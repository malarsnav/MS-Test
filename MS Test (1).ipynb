# %%
print ("Malar!")
# Out:
# Malar!

# %%
import os
os.listdir('data')
# Out:
# ['.ipynb_checkpoints', 'test.txt']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\navak'

# %% [markdown]
# # Header1
# You can also create bullet
# -people
# -love
# -bullets
# So use these as needed!
#
# You can also use numbered lists
# 1.first things first
# 2.then second
# 3.Then third
#
# you can also add links this [count.davesiel](https://www.charityjob.co.uk/jobs/amref-health-africa-uk/data-insights-manager/1027307)

# %% [markdown]
# # Python tutorial

# %%
24*897
# Out:
# 21528

# %% [markdown]
# Adddion

# %%
5677+76382769
# Out:
# 76388446

# %%
my_int = 24

# %%
my_int
# Out:
# 24

# %% [markdown]
# #Data types
#
# ### Numeric
# -Int
# -floats
# -boolean
# ### Non -numeric
# -str: sequence in characters
# ### collection
# -lists-collection of iteams

# %%
my_float = float(my_int)

# %%
type(my_int)
# Out:
# int

# %%
type(my_float)
# Out:
# float

# %% [markdown]
# # Lists
# - There are a collection of itema
# - the lists on the python object

# %%
my_list = ['John','Paul','Rob','simran']

# %%
my_list[0]
# Out:
# 'John'

# %%
my_list[1:3]
# Out:
# ['Paul', 'Rob']

# %%
str.capitalize("malar")
# Out:
# 'Malar'

# %%
my_str="data science"

# %%
my_str.capitalize()
# Out:
# 'Data science'

# %%
my_str.upper()
# Out:
# 'DATA SCIENCE'

# %% [markdown]
# Lists are "mutable" which means they can changes "in place"

# %%
my_list = ['John','george','rob','gin']

# %%
my_list.append('hacker')

# %%
my_list
# Out:
# ['John', 'george', 'rob', 'gin', 'hacker']
